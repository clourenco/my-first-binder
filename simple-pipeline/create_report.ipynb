# %%
# create_report.ipynb

# Load the analysis result
with open('analysis_result.txt', 'r') as f:
    analysis_result = f.read()

# Generate a simple report (e.g., print to a text file)
report_content = f"""
Data Report:

{analysis_result}
"""

# Save the report
with open('final_report.txt', 'w') as f:
    f.write(report_content)

print("Report generated and saved as 'final_report.txt'")
# Out:
# Report generated and saved as 'final_report.txt'
